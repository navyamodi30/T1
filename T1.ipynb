# %% [markdown]
# <a href="https://colab.research.google.com/github/navyamodi30/T1/blob/main/T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/age_gender.csv')
print(data)
# Out:
#       age  ethnicity  gender                        img_name  \
# 0       1          2       0  20161219203650636.jpg.chip.jpg
# 1       1          2       0  20161219222752047.jpg.chip.jpg
# 2       1          2       0  20161219222832191.jpg.chip.jpg
# 3       1          2       0  20161220144911423.jpg.chip.jpg
# 4       1          2       0  20161220144914327.jpg.chip.jpg
# ...   ...        ...     ...                             ...
# 3137    2          2       1  20161219151440283.jpg.chip.jpg
# 3138    2          2       1  20161219151851452.jpg.chip.jpg
# 3139    2          2       1  20161219151908347.jpg.chip.jpg
# 3140    2          2       1  20161219151919100.jpg.chip.jpg
# 3141    2          2       1  20161219151944003.jpg.chip.jpg
#
#                                                  pixels
# 0     129 128 128 126 127 130 133 135 139 142 145 14...
# 1     164 74 111 168 169 171 175 182 184 188 193 199...
# 2     67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('/content/age_gender.csv')

gender_counts = data['gender'].value_counts()

plt.figure(figsize=(8, 5))
gender_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.xlabel('gender')
plt.ylabel('age')
plt.xticks(rotation=0)
plt.show()

plt.figure(figsize=(10, 6))
data['age'].plot(kind='hist', bins=15, color='lightgreen', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
